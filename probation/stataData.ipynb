# %%
import pandas as pd

# %%
df = pd.read_stata('data.dta')
df.head(20
       )
# Out:
#     credits1  credits2  credits_earned1  credits_earned2  session1  \
# 0       2.50      2.50             2.50             2.50     20029
# 1       3.25      2.25             3.25             2.25     20019
# 2       3.00      3.50             3.00             3.00     20009
# 3       2.50      3.50             2.50             3.50     20039
# 4       2.00      0.00             1.50             0.00     19969
# 5       3.00      3.50             3.00             3.50     20039
# 6       2.00      3.00             2.00             3.00     19989
# 7       3.00      4.00             3.00             4.00     19989
# 8       2.50      2.50             1.50             2.50     19989
# 9       3.00      3.50             3.00             3.50     20039
# 10      2.50      2.50             2.50             2.50     20039
# 11      2.50      2.50             2.50             2.50     20039
# 12      2.50      3.00             2.50             3.00     19979
# ...

# %%
df.shape
# Out:
# (44362, 86)

# %%
df.describe()
# Out:
#            credits1      credits2  credits_earned1  credits_earned2  \
# count  44362.000000  44362.000000     44362.000000     44362.000000
# mean       2.799726      2.804214         2.622442         2.683501
# std        0.715258      1.237743         0.835906         1.287028
# min        1.000000      0.000000         0.000000         0.000000
# 25%        2.500000      2.500000         2.000000         2.000000
# 50%        2.500000      3.000000         2.500000         3.000000
# 75%        3.000000      3.500000         3.000000         3.500000
# max       11.000000     13.000000        11.000000        10.500000
#
#            session1     GPA_year1     GPA_year2    CGPA_year1    CGPA_year2  \
# count  44362.000000  44362.000000  38576.000000  44362.000000  38576.000000
# mean   20007.543573      2.437401      2.550520      2.437410      2.531765
# std       23.548698      0.892371      0.833679      0.891981      0.767567
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44362 entries, 0 to 44361
# Data columns (total 86 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   credits1               44362 non-null  float32
#  1   credits2               44362 non-null  float32
#  2   credits_earned1        44362 non-null  float32
#  3   credits_earned2        44362 non-null  float32
#  4   session1               44362 non-null  int16
#  5   winter_ac_standing     44362 non-null  object
#  6   GPA_year1              44362 non-null  float32
#  7   GPA_year2              38576 non-null  float32
#  8   CGPA_year1             44362 non-null  float32
#  9   CGPA_year2             38576 non-null  float32
#  10  totcredits_year1       44362 non-null  float32
#  11  totcredits_year2       43593 non-null  float32
#  12  goodstanding_year1     44362 non-null  int8
#  13  goodstanding_year2     44362 non-null  int8
# ...

# %%
#leaving data of students whose first year GPA is not in the range (-1.4, 1.4) from cut-off
sample14 = df[abs(df['dist_from_cut']) <= 1.4]
sample14.shape
# Out:
# (29601, 86)

# %%
# printing descriptive statictics table (for characteristics variables)

sample14[['hsgrade_pct', 'totcredits_year1', 'age_at_entry', 'male', 'english', 'bpl_north_america', 'loc_campus1', 'loc_campus2', 'loc_campus1']].describe()
# Out:
#         hsgrade_pct  totcredits_year1  age_at_entry          male  \
# count  29601.000000      29601.000000  29601.000000  29601.000000
# mean      40.130333          4.494933     18.703423      0.376913
# std       25.392563          0.523730      0.735467      0.484619
# min        1.000000          3.000000     17.000000      0.000000
# 25%       19.000000          4.000000     18.000000      0.000000
# 50%       38.000000          4.500000     19.000000      0.000000
# 75%       60.000000          5.000000     19.000000      1.000000
# max      100.000000          6.000000     21.000000      1.000000
#
#             english  bpl_north_america   loc_campus1   loc_campus2  \
# count  29601.000000       29601.000000  29601.000000  29601.000000
# mean       0.720955           0.873720      0.528462      0.195095
# std        0.448512           0.332154      0.499172      0.396310
# min        0.000000           0.000000      0.000000      0.000000
# ...

# %%
# printing descriptive statistics table (for outcomes variable)

sample14[['dist_from_cut','probation_year1', 'probation_ever','left_school', 'nextGPA', 'suspended_ever','gradin4', 'gradin5', 'gradin6']].describe()
# Out:
#        dist_from_cut  probation_year1  probation_ever   left_school  \
# count   29601.000000     29601.000000    29601.000000  29601.000000
# mean        0.477412         0.225432        0.279180      0.051586
# std         0.650022         0.417845        0.448612      0.221225
# min        -1.400000         0.000000        0.000000      0.000000
# 25%         0.050000         0.000000        0.000000      0.000000
# 50%         0.590000         0.000000        0.000000      0.000000
# 75%         1.000000         0.000000        1.000000      0.000000
# max         1.400000         1.000000        1.000000      1.000000
#
#             nextGPA  suspended_ever       gradin4       gradin5       gradin6
# count  26834.000000    29601.000000  20353.000000  16710.000000  13587.000000
# mean       0.712986        0.113206      0.367808      0.619090      0.709281
# std        0.841622        0.316796      0.482213      0.485619      0.454093
# ...

# %%
sample14['nextGPA'].describe()
# Out:
# count    26834.000000
# mean         0.712986
# std          0.841622
# min         -1.600000
# 25%          0.200000
# 50%          0.800000
# 75%          1.300000
# max          2.800000
# Name: nextGPA, dtype: float64

# %%
sample14['probation_year1'].describe()
# Out:
# count    29601.000000
# mean         0.225432
# std          0.417845
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: probation_year1, dtype: float64
