# %%
import pandas as pd

# %%
bdf = df = pd.read_stata('auction.dta')
bdf.describe()
# Out:
#                  gw     auctionid     timeended        price  opening_price  \
# count  2.433000e+03  2.433000e+03  2.433000e+03  2433.000000    2183.000000
# mean   1.935515e+11  1.849987e+11  6.083972e-01    88.336937      37.521912
# std    9.807437e+10  9.653023e+10  1.973267e-01   139.312164      89.981476
# min    4.840095e+09  4.441646e+09  5.000000e-09     2.000000       0.010000
# 25%    1.300533e+11  1.300372e+11  4.699884e-01    20.500000       1.000000
# 50%    2.200519e+11  1.900405e+11  6.423611e-01    41.000000       9.990000
# 75%    2.700182e+11  2.600608e+11  7.615509e-01    91.089996      29.990000
# max    3.300505e+11  3.300616e+11  9.951389e-01  1375.000000    1100.000000
#
#        numberofbids  donationpercentage   sellerrating  sellerpercentage  \
# count   1911.000000         2433.000000    2433.000000       2433.000000
# mean      10.242805           19.658857    5601.321003          0.993867
# ...
